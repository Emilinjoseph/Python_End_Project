# %%
import pandas as pd
import numpy as np
import seaborn as snsb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('myexcel - myexcel.csv.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df['Height']=np.random.randint(150,181,size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     180     235
# 2     John Holland  Boston Celtics      30       SG   27     152     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     166     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     154     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     155     203
# 454      Raul Neto       Utah Jazz      25       PG   24     161     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     161     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     159     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.fillna(value={'Salary':0,'College':'Unknown'})
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     180     235
# 2     John Holland  Boston Celtics      30       SG   27     152     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     166     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     154     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     155     203
# 454      Raul Neto       Utah Jazz      25       PG   24     161     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     161     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     159     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
total_emp=len(df.index)
print(((df["Team"].value_counts()/total_emp)*100).round(2))
# Out:
# Team
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# New York Knicks           3.49
# Milwaukee Bucks           3.49
# Brooklyn Nets             3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Miami Heat                3.28
# Charlotte Hornets         3.28
# Atlanta Hawks             3.28
# San Antonio Spurs         3.28
# Houston Rockets           3.28
# Boston Celtics            3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Sacramento Kings          3.28
# Phoenix Suns              3.28
# Los Angeles Lakers        3.28
# Los Angeles Clippers      3.28
# Golden State Warriors     3.28
# Toronto Raptors           3.28
# Philadelphia 76ers        3.28
# Dallas Mavericks          3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# ...

# %% [markdown]
# # 2.Segregate the employees w.r.t different positions.

# %%
arr = df["Position"].unique()
arr
for i in arr:
    print("Position :",i)
    print(df[df['Position']==i].Name)
# Out:
# Position : PG
# 0      Avery Bradley
# 8       Terry Rozier
# 9       Marcus Smart
# 11     Isaiah Thomas
# 19      Jarrett Jack
#            ...
# 440    Brian Roberts
# 443       Trey Burke
# 445       Dante Exum
# 453     Shelvin Mack
# 454        Raul Neto
# Name: Name, Length: 92, dtype: object
# Position : SF
# 1                 Jae Crowder
# 32     Thanasis Antetokounmpo
# 33            Carmelo Anthony
# 35           Cleanthony Early
# 42               Lance Thomas
#                 ...
# 428           Al-Farouq Aminu
# 432          Maurice Harkless
# 448            Gordon Hayward
# 450                Joe Ingles
# 451             Chris Johnson
# Name: Name, Length: 85, dtype: object
# Position : SG
# 2          John Holland
# 3           R.J. Hunter
# 12          Evan Turner
# 13          James Young
# 15     Bojan Bogdanovic
#              ...
# 433    Gerald Henderson
# 437       C.J. McCollum
# 438        Luis Montero
# 444          Alec Burks
# 449         Rodney Hood
# ...

# %% [markdown]
# # 3.Find from which age group most of the employees belong to.

# %%
import matplotlib.pyplot as plt

# Sample data

# Create the histogram plot
plt.hist(df['Age'])

# Customize the plot
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram Plot')

# Display the plot
plt.show()

# %%
import pandas as pd

ages=pd.DataFrame(df['Age'])
bins = [18, 24, 29, 34, 40]
labels = ['18-24', '25-29', '30-34', '35-40']
ages['agerange'] = pd.cut(ages.Age, bins, labels = labels,include_lowest = False)
print("The most of the employees belong to the age group of ",ages['agerange'].value_counts().index[0])
# Out:
# The most of the employees belong to the age group of  25-29

# %% [markdown]
# # 4.Find out under which team and position, spending in terms of salary is high.

# %%
max=df.Salary.max()
dff=df[df['Salary']==max]
print("The team '{}' and the position '{}' spending in terms of salary".format(dff.Team.iloc[0],dff.Position.iloc[0]))
# Out:
# The team 'Los Angeles Lakers' and the position 'SF' spending in terms of salary

# %% [markdown]
# # 5.Find if there is any correlation between age and salary , represent it visually.

# %%
df1=df.drop(['Name', 'Team', 'Position','College', 'Height'], axis='columns')
# Compute correlation matrix
corr = df1.corr()

# Create heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm")

# Add title
plt.title("Correlation Matrix ")

# Show plot
plt.show()
